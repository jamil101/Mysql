# %%
--Sunan Abu Dawood (1493):

-- Allahumma inni as’aluka bi-anna lakal-hamd,
-- la ilaha illa anta,
-- al-Mannaan,
-- Badee‘us-samawati wal-ard,
-- ya dhal-jalali wal-ikram,
-- ya Hayyu ya Qayyum

# %% [markdown]
# **181. Employees Earning More Than Their Managers**
#
# **Easy**
#
# **Companies**: Amazon Facebook Google Yahoo
#
# Table: Employee
# ```
# +-------------+---------+
# | Column Name | Type    |
# +-------------+---------+
# | id          | int     |
# | name        | varchar |
# | salary      | int     |
# | managerId   | int     |
# +-------------+---------+
# ```
# id is the primary key (column with unique values) for this table.
# Each row of this table indicates the ID of an employee, their name, salary, and the ID of their manager.
#
#
# Write a solution to find the employees who earn more than their managers.
#
# Return the result table in any order.
#
# The result format is in the following example.
#
#
#
# **Example 1:**
#
# Input:
# Employee table:
# ```
# +----+-------+--------+-----------+
# | id | name  | salary | managerId |
# +----+-------+--------+-----------+
# | 1  | Joe   | 70000  | 3         |
# | 2  | Henry | 80000  | 4         |
# | 3  | Sam   | 60000  | Null      |
# | 4  | Max   | 90000  | Null      |
# +----+-------+--------+-----------+
# ```
# Output:
# ```
# +----------+
# | Employee |
# +----------+
# | Joe      |
# +----------+
# ```
# **Explanation:** Joe is the only employee who earns more than his manager.

# %%
-- Algorithm:
-- 1. Join Employee table with itself
-- 2. Match employee.managerId = manager.id
-- 3. Compare salaries
-- 4. Return employee name if salary > manager salary

SELECT e.name AS Employee
FROM Employee e
JOIN Employee m
ON e.managerId = m.id
WHERE e.salary > m.salary;

# %%
-- Algorithm:
-- 1. For each employee, find manager salary using subquery
-- 2. Compare employee salary > manager salary
-- 3. Return matching employees

SELECT name AS Employee
FROM Employee e
WHERE salary > (
    SELECT salary
    FROM Employee m
    WHERE m.id = e.managerId
);

# %%
-- Algorithm:
-- 1. Check if a manager exists for employee
-- 2. Compare salary inside EXISTS
-- 3. Return employee if condition satisfied

SELECT e.name AS Employee
FROM Employee e
WHERE EXISTS (
    SELECT 1
    FROM Employee m
    WHERE m.id = e.managerId
    AND e.salary > m.salary
);

# %%
-- Algorithm:
-- 1. LEFT JOIN employee with manager
-- 2. Filter where employee salary > manager salary
-- 3. Ignore NULL managers automatically

SELECT e.name AS Employee
FROM Employee e
LEFT JOIN Employee m
ON e.managerId = m.id
WHERE e.salary > m.salary;

# %%
-- Algorithm:
-- 1. Find employees whose salary is greater than their manager
-- 2. Use IN to filter those employees

SELECT name AS Employee
FROM Employee
WHERE id IN (
    SELECT e.id
    FROM Employee e
    JOIN Employee m
    ON e.managerId = m.id
    WHERE e.salary > m.salary
);
